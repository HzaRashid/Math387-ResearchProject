# %% [markdown]
# Dependencies and imports

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# from google.colab import userdata
# import json
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.metrics import R2Score
import keras.backend as K
from sklearn.metrics import mean_squared_error, explained_variance_score, r2_score
from statistics import stdev
import pandas_datareader as dr
from datetime import date
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# don't install this package unless you want to save the charts

# %%
# !sudo apt install texlive-latex-extra
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   dvisvgm fonts-droid-fallback fonts-lato fonts-lmodern fonts-noto-mono
#   fonts-texgyre fonts-urw-base35 libapache-pom-java libcommons-logging-java
#   libcommons-parent-java libfontbox-java libfontenc1 libgs9 libgs9-common
#   libidn12 libijs-0.35 libjbig2dec0 libkpathsea6 libpdfbox-java libptexenc1
#   libruby3.0 libsynctex2 libteckit0 libtexlua53 libtexluajit2 libwoff1
#   libzzip-0-13 lmodern poppler-data preview-latex-style rake ruby
#   ruby-net-telnet ruby-rubygems ruby-webrick ruby-xmlrpc ruby3.0
#   rubygems-integration t1utils tex-common tex-gyre texlive-base
#   texlive-binaries texlive-fonts-recommended texlive-latex-base
#   texlive-latex-recommended texlive-pictures texlive-plain-generic tipa
#   xfonts-encodings xfonts-utils
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf libavalon-framework-java
#   libcommons-logging-java-doc libexcalibur-logkit-java liblog4j1.2-java
#   poppler-utils ghostscript fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum ri ruby-dev bundler debhelper gv
#   | postscript-viewer perl-tk xpdf | pdf-viewer xzdec
#   texlive-fonts-recommended-doc texlive-latex-base-doc python3-pygments
#   icc-profiles libfile-which-perl libspreadsheet-parseexcel-perl
#   texlive-latex-extra-doc texlive-latex-recommended-doc texlive-luatex
#   texlive-pstricks dot2tex prerex texlive-pictures-doc vprerex
#   default-jre-headless tipa-doc
# The following NEW packages will be installed:
#   dvisvgm fonts-droid-fallback fonts-lato fonts-lmodern fonts-noto-mono
#   fonts-texgyre fonts-urw-base35 libapache-pom-java libcommons-logging-java
#   libcommons-parent-java libfontbox-java libfontenc1 libgs9 libgs9-common
#   libidn12 libijs-0.35 libjbig2dec0 libkpathsea6 libpdfbox-java libptexenc1
#   libruby3.0 libsynctex2 libteckit0 libtexlua53 libtexluajit2 libwoff1
#   libzzip-0-13 lmodern poppler-data preview-latex-style rake ruby
#   ruby-net-telnet ruby-rubygems ruby-webrick ruby-xmlrpc ruby3.0
#   rubygems-integration t1utils tex-common tex-gyre texlive-base
#   texlive-binaries texlive-fonts-recommended texlive-latex-base
#   texlive-latex-extra texlive-latex-recommended texlive-pictures
#   texlive-plain-generic tipa xfonts-encodings xfonts-utils
# 0 upgraded, 52 newly installed, 0 to remove and 45 not upgraded.
# Need to get 169 MB of archives.
# After this operation, 552 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1build1 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-lato all 2.0-2.1 [2,696 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2,171 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tex-common all 6.17 [33.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-urw-base35 all 20200910-1 [6,367 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9-common all 9.55.0~dfsg1-0ubuntu5.6 [751 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libidn12 amd64 1.38-4ubuntu1 [60.0 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libijs-0.35 amd64 0.35-15build2 [16.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjbig2dec0 amd64 0.19-3build2 [64.7 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9 amd64 9.55.0~dfsg1-0ubuntu5.6 [5,031 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libkpathsea6 amd64 2021.20210626.59705-1ubuntu0.2 [60.4 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwoff1 amd64 1.0.2-1build4 [45.2 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/universe amd64 dvisvgm amd64 2.13.1-1 [1,221 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-lmodern all 2.004.5-6.1 [4,532 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-mono all 20201225-1build1 [397 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-texgyre all 20180621-3.1 [10.2 MB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libapache-pom-java all 18-1 [4,720 B]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcommons-parent-java all 43-1 [10.8 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcommons-logging-java all 1.2-2 [60.3 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libptexenc1 amd64 2021.20210626.59705-1ubuntu0.2 [39.1 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 rubygems-integration all 1.18 [5,336 B]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ruby3.0 amd64 3.0.2-7ubuntu2.4 [50.1 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 ruby-rubygems all 3.3.5-2 [228 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 ruby amd64 1:3.0~exp1 [5,100 B]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 rake all 13.0.6-2 [61.7 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 ruby-net-telnet all 0.1.1-2 [12.6 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ruby-webrick all 1.7.0-3 [51.8 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ruby-xmlrpc all 0.3.2-1ubuntu0.1 [24.9 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libruby3.0 amd64 3.0.2-7ubuntu2.4 [5,113 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsynctex2 amd64 2021.20210626.59705-1ubuntu0.2 [55.6 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libteckit0 amd64 2.5.11+ds1-1 [421 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtexlua53 amd64 2021.20210626.59705-1ubuntu0.2 [120 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtexluajit2 amd64 2021.20210626.59705-1ubuntu0.2 [267 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzzip-0-13 amd64 0.13.72+dfsg.1-1.1 [27.0 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lmodern all 2.004.5-6.1 [9,471 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/universe amd64 preview-latex-style all 12.2-1ubuntu1 [185 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 t1utils amd64 1.41-4build2 [61.3 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tex-gyre all 20180621-3.1 [6,209 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 texlive-binaries amd64 2021.20210626.59705-1ubuntu0.2 [9,860 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-base all 2021.20220204-1 [21.0 MB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-fonts-recommended all 2021.20220204-1 [4,972 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-latex-base all 2021.20220204-1 [1,128 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfontbox-java all 1:1.8.16-2 [207 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libpdfbox-java all 1:1.8.16-2 [5,199 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-latex-recommended all 2021.20220204-1 [14.4 MB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-pictures all 2021.20220204-1 [8,720 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-latex-extra all 2021.20220204-1 [13.9 MB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-plain-generic all 2021.20220204-1 [27.5 MB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tipa all 2:1.3-21 [2,967 kB]
# Fetched 169 MB in 9s (18.7 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 52.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 121752 files and directories currently installed.)
# Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1build1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Selecting previously unselected package fonts-lato.
# Preparing to unpack .../01-fonts-lato_2.0-2.1_all.deb ...
# Unpacking fonts-lato (2.0-2.1) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../02-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package tex-common.
# Preparing to unpack .../03-tex-common_6.17_all.deb ...
# Unpacking tex-common (6.17) ...
# Selecting previously unselected package fonts-urw-base35.
# Preparing to unpack .../04-fonts-urw-base35_20200910-1_all.deb ...
# Unpacking fonts-urw-base35 (20200910-1) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../05-libgs9-common_9.55.0~dfsg1-0ubuntu5.6_all.deb ...
# Unpacking libgs9-common (9.55.0~dfsg1-0ubuntu5.6) ...
# Selecting previously unselected package libidn12:amd64.
# Preparing to unpack .../06-libidn12_1.38-4ubuntu1_amd64.deb ...
# Unpacking libidn12:amd64 (1.38-4ubuntu1) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../07-libijs-0.35_0.35-15build2_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-15build2) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../08-libjbig2dec0_0.19-3build2_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.19-3build2) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../09-libgs9_9.55.0~dfsg1-0ubuntu5.6_amd64.deb ...
# Unpacking libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.6) ...
# Selecting previously unselected package libkpathsea6:amd64.
# Preparing to unpack .../10-libkpathsea6_2021.20210626.59705-1ubuntu0.2_amd64.deb ...
# Unpacking libkpathsea6:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Selecting previously unselected package libwoff1:amd64.
# Preparing to unpack .../11-libwoff1_1.0.2-1build4_amd64.deb ...
# Unpacking libwoff1:amd64 (1.0.2-1build4) ...
# Selecting previously unselected package dvisvgm.
# Preparing to unpack .../12-dvisvgm_2.13.1-1_amd64.deb ...
# Unpacking dvisvgm (2.13.1-1) ...
# Selecting previously unselected package fonts-lmodern.
# Preparing to unpack .../13-fonts-lmodern_2.004.5-6.1_all.deb ...
# Unpacking fonts-lmodern (2.004.5-6.1) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../14-fonts-noto-mono_20201225-1build1_all.deb ...
# Unpacking fonts-noto-mono (20201225-1build1) ...
# Selecting previously unselected package fonts-texgyre.
# Preparing to unpack .../15-fonts-texgyre_20180621-3.1_all.deb ...
# Unpacking fonts-texgyre (20180621-3.1) ...
# Selecting previously unselected package libapache-pom-java.
# Preparing to unpack .../16-libapache-pom-java_18-1_all.deb ...
# Unpacking libapache-pom-java (18-1) ...
# Selecting previously unselected package libcommons-parent-java.
# Preparing to unpack .../17-libcommons-parent-java_43-1_all.deb ...
# Unpacking libcommons-parent-java (43-1) ...
# Selecting previously unselected package libcommons-logging-java.
# Preparing to unpack .../18-libcommons-logging-java_1.2-2_all.deb ...
# Unpacking libcommons-logging-java (1.2-2) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../19-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libptexenc1:amd64.
# Preparing to unpack .../20-libptexenc1_2021.20210626.59705-1ubuntu0.2_amd64.deb ...
# Unpacking libptexenc1:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Selecting previously unselected package rubygems-integration.
# Preparing to unpack .../21-rubygems-integration_1.18_all.deb ...
# Unpacking rubygems-integration (1.18) ...
# Selecting previously unselected package ruby3.0.
# Preparing to unpack .../22-ruby3.0_3.0.2-7ubuntu2.4_amd64.deb ...
# Unpacking ruby3.0 (3.0.2-7ubuntu2.4) ...
# Selecting previously unselected package ruby-rubygems.
# Preparing to unpack .../23-ruby-rubygems_3.3.5-2_all.deb ...
# Unpacking ruby-rubygems (3.3.5-2) ...
# Selecting previously unselected package ruby.
# Preparing to unpack .../24-ruby_1%3a3.0~exp1_amd64.deb ...
# Unpacking ruby (1:3.0~exp1) ...
# Selecting previously unselected package rake.
# Preparing to unpack .../25-rake_13.0.6-2_all.deb ...
# Unpacking rake (13.0.6-2) ...
# Selecting previously unselected package ruby-net-telnet.
# Preparing to unpack .../26-ruby-net-telnet_0.1.1-2_all.deb ...
# Unpacking ruby-net-telnet (0.1.1-2) ...
# Selecting previously unselected package ruby-webrick.
# Preparing to unpack .../27-ruby-webrick_1.7.0-3_all.deb ...
# Unpacking ruby-webrick (1.7.0-3) ...
# Selecting previously unselected package ruby-xmlrpc.
# Preparing to unpack .../28-ruby-xmlrpc_0.3.2-1ubuntu0.1_all.deb ...
# Unpacking ruby-xmlrpc (0.3.2-1ubuntu0.1) ...
# Selecting previously unselected package libruby3.0:amd64.
# Preparing to unpack .../29-libruby3.0_3.0.2-7ubuntu2.4_amd64.deb ...
# Unpacking libruby3.0:amd64 (3.0.2-7ubuntu2.4) ...
# Selecting previously unselected package libsynctex2:amd64.
# Preparing to unpack .../30-libsynctex2_2021.20210626.59705-1ubuntu0.2_amd64.deb ...
# Unpacking libsynctex2:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Selecting previously unselected package libteckit0:amd64.
# Preparing to unpack .../31-libteckit0_2.5.11+ds1-1_amd64.deb ...
# Unpacking libteckit0:amd64 (2.5.11+ds1-1) ...
# Selecting previously unselected package libtexlua53:amd64.
# Preparing to unpack .../32-libtexlua53_2021.20210626.59705-1ubuntu0.2_amd64.deb ...
# Unpacking libtexlua53:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Selecting previously unselected package libtexluajit2:amd64.
# Preparing to unpack .../33-libtexluajit2_2021.20210626.59705-1ubuntu0.2_amd64.deb ...
# Unpacking libtexluajit2:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Selecting previously unselected package libzzip-0-13:amd64.
# Preparing to unpack .../34-libzzip-0-13_0.13.72+dfsg.1-1.1_amd64.deb ...
# Unpacking libzzip-0-13:amd64 (0.13.72+dfsg.1-1.1) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../35-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../36-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package lmodern.
# Preparing to unpack .../37-lmodern_2.004.5-6.1_all.deb ...
# Unpacking lmodern (2.004.5-6.1) ...
# Selecting previously unselected package preview-latex-style.
# Preparing to unpack .../38-preview-latex-style_12.2-1ubuntu1_all.deb ...
# Unpacking preview-latex-style (12.2-1ubuntu1) ...
# Selecting previously unselected package t1utils.
# Preparing to unpack .../39-t1utils_1.41-4build2_amd64.deb ...
# Unpacking t1utils (1.41-4build2) ...
# Selecting previously unselected package tex-gyre.
# Preparing to unpack .../40-tex-gyre_20180621-3.1_all.deb ...
# Unpacking tex-gyre (20180621-3.1) ...
# Selecting previously unselected package texlive-binaries.
# Preparing to unpack .../41-texlive-binaries_2021.20210626.59705-1ubuntu0.2_amd64.deb ...
# Unpacking texlive-binaries (2021.20210626.59705-1ubuntu0.2) ...
# Selecting previously unselected package texlive-base.
# Preparing to unpack .../42-texlive-base_2021.20220204-1_all.deb ...
# Unpacking texlive-base (2021.20220204-1) ...
# Selecting previously unselected package texlive-fonts-recommended.
# Preparing to unpack .../43-texlive-fonts-recommended_2021.20220204-1_all.deb ...
# Unpacking texlive-fonts-recommended (2021.20220204-1) ...
# Selecting previously unselected package texlive-latex-base.
# Preparing to unpack .../44-texlive-latex-base_2021.20220204-1_all.deb ...
# Unpacking texlive-latex-base (2021.20220204-1) ...
# Selecting previously unselected package libfontbox-java.
# Preparing to unpack .../45-libfontbox-java_1%3a1.8.16-2_all.deb ...
# Unpacking libfontbox-java (1:1.8.16-2) ...
# Selecting previously unselected package libpdfbox-java.
# Preparing to unpack .../46-libpdfbox-java_1%3a1.8.16-2_all.deb ...
# Unpacking libpdfbox-java (1:1.8.16-2) ...
# Selecting previously unselected package texlive-latex-recommended.
# Preparing to unpack .../47-texlive-latex-recommended_2021.20220204-1_all.deb ...
# Unpacking texlive-latex-recommended (2021.20220204-1) ...
# Selecting previously unselected package texlive-pictures.
# Preparing to unpack .../48-texlive-pictures_2021.20220204-1_all.deb ...
# Unpacking texlive-pictures (2021.20220204-1) ...
# Selecting previously unselected package texlive-latex-extra.
# Preparing to unpack .../49-texlive-latex-extra_2021.20220204-1_all.deb ...
# Unpacking texlive-latex-extra (2021.20220204-1) ...
# Selecting previously unselected package texlive-plain-generic.
# Preparing to unpack .../50-texlive-plain-generic_2021.20220204-1_all.deb ...
# Unpacking texlive-plain-generic (2021.20220204-1) ...
# Selecting previously unselected package tipa.
# Preparing to unpack .../51-tipa_2%3a1.3-21_all.deb ...
# Unpacking tipa (2:1.3-21) ...
# Setting up fonts-lato (2.0-2.1) ...
# Setting up fonts-noto-mono (20201225-1build1) ...
# Setting up libwoff1:amd64 (1.0.2-1build4) ...
# Setting up libtexlua53:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Setting up libijs-0.35:amd64 (0.35-15build2) ...
# Setting up libtexluajit2:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Setting up libfontbox-java (1:1.8.16-2) ...
# Setting up rubygems-integration (1.18) ...
# Setting up libzzip-0-13:amd64 (0.13.72+dfsg.1-1.1) ...
# Setting up fonts-urw-base35 (20200910-1) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up tex-common (6.17) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# update-language: texlive-base not installed and configured, doing nothing!
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up libjbig2dec0:amd64 (0.19-3build2) ...
# Setting up libteckit0:amd64 (2.5.11+ds1-1) ...
# Setting up libapache-pom-java (18-1) ...
# Setting up ruby-net-telnet (0.1.1-2) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up t1utils (1.41-4build2) ...
# Setting up libidn12:amd64 (1.38-4ubuntu1) ...
# Setting up fonts-texgyre (20180621-3.1) ...
# Setting up libkpathsea6:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Setting up ruby-webrick (1.7.0-3) ...
# Setting up fonts-lmodern (2.004.5-6.1) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Setting up ruby-xmlrpc (0.3.2-1ubuntu0.1) ...
# Setting up libsynctex2:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Setting up libgs9-common (9.55.0~dfsg1-0ubuntu5.6) ...
# Setting up libpdfbox-java (1:1.8.16-2) ...
# Setting up libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.6) ...
# Setting up preview-latex-style (12.2-1ubuntu1) ...
# Setting up libcommons-parent-java (43-1) ...
# Setting up dvisvgm (2.13.1-1) ...
# Setting up libcommons-logging-java (1.2-2) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up libptexenc1:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Setting up texlive-binaries (2021.20210626.59705-1ubuntu0.2) ...
# update-alternatives: using /usr/bin/xdvi-xaw to provide /usr/bin/xdvi.bin (xdvi.bin) in auto mode
# update-alternatives: using /usr/bin/bibtex.original to provide /usr/bin/bibtex (bibtex) in auto mode
# Setting up lmodern (2.004.5-6.1) ...
# Setting up texlive-base (2021.20220204-1) ...
# /usr/bin/ucfr
# /usr/bin/ucfr
# /usr/bin/ucfr
# /usr/bin/ucfr
# mktexlsr: Updating /var/lib/texmf/ls-R-TEXLIVEDIST...
# mktexlsr: Updating /var/lib/texmf/ls-R-TEXMFMAIN...
# mktexlsr: Updating /var/lib/texmf/ls-R...
# mktexlsr: Done.
# tl-paper: setting paper size for dvips to a4: /var/lib/texmf/dvips/config/config-paper.ps
# tl-paper: setting paper size for dvipdfmx to a4: /var/lib/texmf/dvipdfmx/dvipdfmx-paper.cfg
# tl-paper: setting paper size for xdvi to a4: /var/lib/texmf/xdvi/XDvi-paper
# tl-paper: setting paper size for pdftex to a4: /var/lib/texmf/tex/generic/tex-ini-files/pdftexconfig.tex
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Setting up tex-gyre (20180621-3.1) ...
# Setting up texlive-plain-generic (2021.20220204-1) ...
# Setting up texlive-latex-base (2021.20220204-1) ...
# Setting up texlive-latex-recommended (2021.20220204-1) ...
# Setting up texlive-pictures (2021.20220204-1) ...
# Setting up texlive-fonts-recommended (2021.20220204-1) ...
# Setting up tipa (2:1.3-21) ...
# Setting up texlive-latex-extra (2021.20220204-1) ...
# Setting up libruby3.0:amd64 (3.0.2-7ubuntu2.4) ...
# Setting up ruby3.0 (3.0.2-7ubuntu2.4) ...
# Setting up ruby (1:3.0~exp1) ...
# Setting up rake (13.0.6-2) ...
# Setting up ruby-rubygems (3.3.5-2) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# Processing triggers for tex-common (6.17) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Running updmap-sys. This may take some time... done.
# Running mktexlsr /var/lib/texmf ... done.
# Building format(s) --all.
# 	This may take some time... done.

# %%
# define date range for stock
start_date = "1950-01-01"
curr_date = date.today()

# number of days used to make prediction
trail = 730 # 2 years

# define neural network model
def model_regression():
    m = Sequential()
    m.add(LSTM(units=8, input_shape=(trail, 1)))
    m.add(Dense(units=8, activation='gelu'))
    m.add(Dense(units=1))
    return m

# %%
# Fetch the data from Yahoo Finance
df = yf.download('^GSPC', start_date, curr_date)

raw_data = df.filter(['Close'])

raw_data = raw_data.replace(',', '', regex=True)

# normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = pd.DataFrame(scaler.fit_transform(raw_data))
scaled_data = scaled_data.rename(columns={0: 'Close'})

# use 75% of data to train model, 25% to test
train_data_size = int(0.75 * len(raw_data))
train_data = scaled_data[:train_data_size]

# subtract tail since its is needed to predict 1st day of test data
test_data = scaled_data[train_data_size-trail:]
test_data = test_data.rename(columns={0: 'Close'})

# convert train and test data to numpy arrays
train_data_array = np.array(train_data)
test_data_array = np.array(test_data)

# split train data into inputs and targets
x_train, y_train = [], []
for i in range(train_data_array.shape[0] - trail):
  x_train.append(train_data_array[i:i + trail])    # input will be closing prices from tail days
  y_train.append(train_data_array[i + trail, 0])   # target will be closing price one day after

x_train, y_train = np.array(x_train), np.array(y_train)

# split test data into inputs and targets
x_test, y_test = [], []
for i in range(test_data_array.shape[0] - trail):
  x_test.append(test_data_array[i:i + trail])
  y_test.append(test_data_array[i + trail])

# convert to numpy arrays to be read for training
x_test, y_test = np.array(x_test), np.array(y_test)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
from keras.optimizers import SGD, RMSprop, Adam
batch_sizes = [train_data_size, 1024, 512, 128, 64, 32, 1]

# load optimization algorithms
def fetch_algs():
  plain = SGD(learning_rate = 0.001, momentum = 0.0, name = 'Plain')
  momentum = SGD(learning_rate = 0.001, momentum=0.9, name = 'Momentum')
  rmsprop = RMSprop(learning_rate = 0.001, name = 'RMSprop')
  adam = Adam(learning_rate = 0.001, name = 'Adam')

  return [plain, momentum, rmsprop, adam]

# %%
for size in batch_sizes:
  opt_algs = fetch_algs()
  for alg in opt_algs:
    print(f'==================== BATCH SIZE = {size}, OPT_ALG = {alg.name} ====================\n\n')
    model = model_regression()
    model.compile(
        loss='log_cosh',
        optimizer=alg,
        metrics=['mean_squared_error','mean_absolute_error', 'mean_absolute_percentage_error']
        )
    model.summary()

    history = model.fit(x_train, y_train, batch_size = size, epochs = 30)

    loss_stdev = stdev(history.history['loss'])
    mse_stdev = stdev(history.history['mean_squared_error'])
    mae_stdev = stdev(history.history['mean_absolute_error'])
    mape_stdev = stdev(history.history['mean_absolute_percentage_error'])
    print(f'\n\nLoss St.Dev: {loss_stdev} - MSE St.Dev: {mse_stdev} - MAE Std.Dev: {mae_stdev} - MAPE St.Dev: {mape_stdev}\n\n')

    # unscale the predictions to they can be inserted into to the test data
    scaled_predictions = model.predict(x_test)
    predictions = scaler.inverse_transform(scaled_predictions)
    actual = scaler.inverse_transform(y_test)

    residuals = actual - predictions

    plt.style.use('seaborn')
    # 1. Training & Validation Loss Plot
    plt.figure(figsize=(6, 4))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.title(f'Training Loss ({alg.name}, Batch Size = {size})')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    plt.savefig(f'P1-BS{size}-{alg.name}.pgf')

    # 2. Actual vs Predicted - Line Chart
    plt.figure(figsize=(6, 4))
    plt.plot(actual, label='Actual Values', linestyle='-', marker='o', color='b')
    plt.plot(predictions, label='Predictions', linestyle='-', marker='x', color='r')
    plt.title(f'Actual vs. Predicted Values ({alg.name}, Batch Size = {size})')
    plt.xlabel('Time')
    plt.ylabel('Value')
    plt.legend()
    plt.savefig(f'P2-BS{size}-{alg.name}.pgf')
    plt.show()

    # 3. Actual vs Predicted - Scatter Plot
    plt.figure(figsize=(6, 4))
    plt.scatter(actual, predictions, alpha=0.5, color='purple')
    plt.title(f'Correlation between Actual and Predictions ({alg.name}, Batch Size = {size})')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.plot([min(actual), max(actual)], [min(actual), max(actual)], 'k--', lw=2)  # Line of perfect fit
    plt.savefig(f'P3-BS{size}-{alg.name}.pgf')
    plt.show()

    # 4. Histogram of Residuals
    residuals = actual.flatten() - predictions.flatten()
    plt.figure(figsize=(6, 4))
    plt.hist(residuals, bins=30, color='gray', alpha=0.7)
    plt.title(f'Histogram of Prediction Residuals ({alg.name}, Batch Size = {size})')
    plt.xlabel('Residuals')
    plt.ylabel('Frequency')
    plt.savefig(f'P4-BS{size}-{alg.name}.pgf')
    plt.show()

    print(f'==================== ==================== ==================== ==================== ==================== ==================== ====================\n')
    print(f'==================== ==================== ==================== ==================== ==================== ==================== ====================\n\n')
# Out:
# ==================== BATCH SIZE = 14022, OPT_ALG = Plain ====================
#
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 8)                 320
#
#  dense (Dense)               (None, 8)                 72
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 401 (1.57 KB)
# Trainable params: 401 (1.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 1/1 [==============================] - 8s 8s/step - loss: 0.0042 - mean_squared_error: 0.0084 - mean_absolute_error: 0.0570 - mean_absolute_percentage_error: 96.7210
# Epoch 2/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0042 - mean_squared_error: 0.0084 - mean_absolute_error: 0.0569 - mean_absolute_percentage_error: 95.9625
# Epoch 3/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0042 - mean_squared_error: 0.0084 - mean_absolute_error: 0.0568 - mean_absolute_percentage_error: 95.2054
# Epoch 4/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0042 - mean_squared_error: 0.0084 - mean_absolute_error: 0.0567 - mean_absolute_percentage_error: 94.4495
# Epoch 5/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0042 - mean_squared_error: 0.0084 - mean_absolute_error: 0.0566 - mean_absolute_percentage_error: 93.6950
# Epoch 6/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0042 - mean_squared_error: 0.0084 - mean_absolute_error: 0.0565 - mean_absolute_percentage_error: 92.9417
# Epoch 7/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0042 - mean_squared_error: 0.0084 - mean_absolute_error: 0.0564 - mean_absolute_percentage_error: 92.1897
# Epoch 8/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0042 - mean_squared_error: 0.0084 - mean_absolute_error: 0.0563 - mean_absolute_percentage_error: 91.4390
# Epoch 9/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0042 - mean_squared_error: 0.0084 - mean_absolute_error: 0.0562 - mean_absolute_percentage_error: 90.6895
# Epoch 10/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0041 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0561 - mean_absolute_percentage_error: 89.9414
# Epoch 11/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0041 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0560 - mean_absolute_percentage_error: 89.1945
# Epoch 12/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0041 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0559 - mean_absolute_percentage_error: 88.4489
# Epoch 13/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0041 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0558 - mean_absolute_percentage_error: 87.7064
# Epoch 14/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0041 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0557 - mean_absolute_percentage_error: 86.9774
# Epoch 15/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0041 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0556 - mean_absolute_percentage_error: 86.2800
# Epoch 16/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0041 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0555 - mean_absolute_percentage_error: 85.6338
# Epoch 17/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0041 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0554 - mean_absolute_percentage_error: 85.0606
# Epoch 18/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0041 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0553 - mean_absolute_percentage_error: 84.5229
# Epoch 19/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0041 - mean_squared_error: 0.0082 - mean_absolute_error: 0.0552 - mean_absolute_percentage_error: 84.0169
# Epoch 20/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0041 - mean_squared_error: 0.0082 - mean_absolute_error: 0.0551 - mean_absolute_percentage_error: 83.5653
# Epoch 21/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0041 - mean_squared_error: 0.0082 - mean_absolute_error: 0.0550 - mean_absolute_percentage_error: 83.1337
# Epoch 22/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0041 - mean_squared_error: 0.0082 - mean_absolute_error: 0.0549 - mean_absolute_percentage_error: 82.7082
# Epoch 23/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0041 - mean_squared_error: 0.0082 - mean_absolute_error: 0.0548 - mean_absolute_percentage_error: 82.2911
# Epoch 24/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0041 - mean_squared_error: 0.0082 - mean_absolute_error: 0.0547 - mean_absolute_percentage_error: 81.8818
# Epoch 25/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0041 - mean_squared_error: 0.0082 - mean_absolute_error: 0.0546 - mean_absolute_percentage_error: 81.4847
# Epoch 26/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0041 - mean_squared_error: 0.0082 - mean_absolute_error: 0.0546 - mean_absolute_percentage_error: 81.0980
# Epoch 27/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0041 - mean_squared_error: 0.0082 - mean_absolute_error: 0.0545 - mean_absolute_percentage_error: 80.7175
# Epoch 28/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0040 - mean_squared_error: 0.0082 - mean_absolute_error: 0.0544 - mean_absolute_percentage_error: 80.3473
# Epoch 29/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0040 - mean_squared_error: 0.0081 - mean_absolute_error: 0.0543 - mean_absolute_percentage_error: 79.9871
# Epoch 30/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0040 - mean_squared_error: 0.0081 - mean_absolute_error: 0.0542 - mean_absolute_percentage_error: 79.6322
#
#
# Loss St.Dev: 4.7748875527981716e-05 - MSE St.Dev: 9.642200707193395e-05 - MAE Std.Dev: 0.0008387289914830458 - MAPE St.Dev: 5.321090902452916
#
#
# 147/147 [==============================] - 7s 46ms/step
# <ipython-input-6-c8dce139631b>:28: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# ==================== ==================== ==================== ==================== ==================== ==================== ====================
#
# ==================== ==================== ==================== ==================== ==================== ==================== ====================
#
#
# ==================== BATCH SIZE = 14022, OPT_ALG = Momentum ====================
#
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 8)                 320
#
#  dense_2 (Dense)             (None, 8)                 72
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 401 (1.57 KB)
# Trainable params: 401 (1.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 1/1 [==============================] - 7s 7s/step - loss: 0.0048 - mean_squared_error: 0.0097 - mean_absolute_error: 0.0608 - mean_absolute_percentage_error: 102.6915
# Epoch 2/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0048 - mean_squared_error: 0.0096 - mean_absolute_error: 0.0606 - mean_absolute_percentage_error: 101.6180
# Epoch 3/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0048 - mean_squared_error: 0.0096 - mean_absolute_error: 0.0603 - mean_absolute_percentage_error: 99.5807
# Epoch 4/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0047 - mean_squared_error: 0.0096 - mean_absolute_error: 0.0600 - mean_absolute_percentage_error: 96.6806
# Epoch 5/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0047 - mean_squared_error: 0.0095 - mean_absolute_error: 0.0595 - mean_absolute_percentage_error: 93.0133
# Epoch 6/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0047 - mean_squared_error: 0.0094 - mean_absolute_error: 0.0589 - mean_absolute_percentage_error: 89.3730
# Epoch 7/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0046 - mean_squared_error: 0.0094 - mean_absolute_error: 0.0583 - mean_absolute_percentage_error: 86.4981
# Epoch 8/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0046 - mean_squared_error: 0.0093 - mean_absolute_error: 0.0576 - mean_absolute_percentage_error: 83.7501
# Epoch 9/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0046 - mean_squared_error: 0.0092 - mean_absolute_error: 0.0569 - mean_absolute_percentage_error: 81.0736
# Epoch 10/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0045 - mean_squared_error: 0.0091 - mean_absolute_error: 0.0561 - mean_absolute_percentage_error: 78.6003
# Epoch 11/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0045 - mean_squared_error: 0.0090 - mean_absolute_error: 0.0553 - mean_absolute_percentage_error: 76.7222
# Epoch 12/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0044 - mean_squared_error: 0.0089 - mean_absolute_error: 0.0546 - mean_absolute_percentage_error: 75.8634
# Epoch 13/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0044 - mean_squared_error: 0.0088 - mean_absolute_error: 0.0539 - mean_absolute_percentage_error: 75.3847
# Epoch 14/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0043 - mean_squared_error: 0.0087 - mean_absolute_error: 0.0532 - mean_absolute_percentage_error: 75.7367
# Epoch 15/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0042 - mean_squared_error: 0.0086 - mean_absolute_error: 0.0525 - mean_absolute_percentage_error: 76.5968
# Epoch 16/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0042 - mean_squared_error: 0.0084 - mean_absolute_error: 0.0518 - mean_absolute_percentage_error: 77.9375
# Epoch 17/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0041 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0512 - mean_absolute_percentage_error: 79.8127
# Epoch 18/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0041 - mean_squared_error: 0.0082 - mean_absolute_error: 0.0507 - mean_absolute_percentage_error: 82.0226
# Epoch 19/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0040 - mean_squared_error: 0.0081 - mean_absolute_error: 0.0501 - mean_absolute_percentage_error: 84.7193
# Epoch 20/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0040 - mean_squared_error: 0.0080 - mean_absolute_error: 0.0497 - mean_absolute_percentage_error: 88.1460
# Epoch 21/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0039 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0494 - mean_absolute_percentage_error: 92.3878
# Epoch 22/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0039 - mean_squared_error: 0.0078 - mean_absolute_error: 0.0492 - mean_absolute_percentage_error: 97.4450
# Epoch 23/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0038 - mean_squared_error: 0.0077 - mean_absolute_error: 0.0492 - mean_absolute_percentage_error: 103.2235
# Epoch 24/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0038 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0492 - mean_absolute_percentage_error: 109.3665
# Epoch 25/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0038 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0492 - mean_absolute_percentage_error: 115.6512
# Epoch 26/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0037 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0493 - mean_absolute_percentage_error: 122.0040
# Epoch 27/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0037 - mean_squared_error: 0.0074 - mean_absolute_error: 0.0494 - mean_absolute_percentage_error: 128.3680
# Epoch 28/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0036 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0495 - mean_absolute_percentage_error: 134.7458
# Epoch 29/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0036 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0496 - mean_absolute_percentage_error: 141.1145
# Epoch 30/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0036 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0497 - mean_absolute_percentage_error: 147.4221
#
#
# Loss St.Dev: 0.00041104152467466755 - MSE St.Dev: 0.0008316235067256269 - MAE Std.Dev: 0.004292994934898696 - MAPE St.Dev: 20.675410175726643
#
#
# 147/147 [==============================] - 7s 45ms/step
# <ipython-input-6-c8dce139631b>:28: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# ==================== ==================== ==================== ==================== ==================== ==================== ====================
#
# ==================== ==================== ==================== ==================== ==================== ==================== ====================
#
#
# ==================== BATCH SIZE = 14022, OPT_ALG = RMSprop ====================
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 8)                 320
#
#  dense_4 (Dense)             (None, 8)                 72
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 401 (1.57 KB)
# Trainable params: 401 (1.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 1/1 [==============================] - 7s 7s/step - loss: 0.0053 - mean_squared_error: 0.0106 - mean_absolute_error: 0.0639 - mean_absolute_percentage_error: 108.2729
# Epoch 2/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0046 - mean_squared_error: 0.0094 - mean_absolute_error: 0.0550 - mean_absolute_percentage_error: 80.4043
# Epoch 3/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0043 - mean_squared_error: 0.0086 - mean_absolute_error: 0.0516 - mean_absolute_percentage_error: 96.6101
# Epoch 4/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0040 - mean_squared_error: 0.0081 - mean_absolute_error: 0.0513 - mean_absolute_percentage_error: 125.4651
# Epoch 5/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0038 - mean_squared_error: 0.0077 - mean_absolute_error: 0.0517 - mean_absolute_percentage_error: 152.7577
# Epoch 6/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0037 - mean_squared_error: 0.0074 - mean_absolute_error: 0.0521 - mean_absolute_percentage_error: 177.0555
# Epoch 7/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0036 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0527 - mean_absolute_percentage_error: 199.2480
# Epoch 8/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0035 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0533 - mean_absolute_percentage_error: 219.4363
# Epoch 9/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0034 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0538 - mean_absolute_percentage_error: 237.8230
# Epoch 10/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0033 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0544 - mean_absolute_percentage_error: 254.5914
# Epoch 11/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0032 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0548 - mean_absolute_percentage_error: 269.8967
# Epoch 12/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0032 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0553 - mean_absolute_percentage_error: 283.9192
# Epoch 13/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0032 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0557 - mean_absolute_percentage_error: 296.7776
# Epoch 14/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0031 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0562 - mean_absolute_percentage_error: 308.5183
# Epoch 15/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0031 - mean_squared_error: 0.0062 - mean_absolute_error: 0.0566 - mean_absolute_percentage_error: 319.1846
# Epoch 16/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0031 - mean_squared_error: 0.0062 - mean_absolute_error: 0.0569 - mean_absolute_percentage_error: 328.8352
# Epoch 17/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0030 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0573 - mean_absolute_percentage_error: 337.5004
# Epoch 18/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0030 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0576 - mean_absolute_percentage_error: 345.2156
# Epoch 19/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0030 - mean_squared_error: 0.0060 - mean_absolute_error: 0.0578 - mean_absolute_percentage_error: 352.0267
# Epoch 20/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0030 - mean_squared_error: 0.0060 - mean_absolute_error: 0.0581 - mean_absolute_percentage_error: 357.9798
# Epoch 21/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0030 - mean_squared_error: 0.0060 - mean_absolute_error: 0.0583 - mean_absolute_percentage_error: 363.1165
# Epoch 22/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0030 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0584 - mean_absolute_percentage_error: 367.4874
# Epoch 23/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0029 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0585 - mean_absolute_percentage_error: 371.1488
# Epoch 24/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0029 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0586 - mean_absolute_percentage_error: 374.1550
# Epoch 25/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0029 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0587 - mean_absolute_percentage_error: 376.5642
# Epoch 26/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0029 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0587 - mean_absolute_percentage_error: 378.4368
# Epoch 27/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0029 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0587 - mean_absolute_percentage_error: 379.8326
# Epoch 28/30
# 1/1 [==============================] - 8s 8s/step - loss: 0.0029 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0587 - mean_absolute_percentage_error: 380.8111
# Epoch 29/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0029 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0586 - mean_absolute_percentage_error: 381.4299
# Epoch 30/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0029 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0586 - mean_absolute_percentage_error: 381.7439
#
#
# Loss St.Dev: 0.0005782032073488188 - MSE St.Dev: 0.0011737587947286533 - MAE Std.Dev: 0.002881939903371585 - MAPE St.Dev: 98.31426826875932
#
#
# 147/147 [==============================] - 6s 41ms/step
# <ipython-input-6-c8dce139631b>:28: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# ==================== ==================== ==================== ==================== ==================== ==================== ====================
#
# ==================== ==================== ==================== ==================== ==================== ==================== ====================
#
#
# ==================== BATCH SIZE = 14022, OPT_ALG = Adam ====================
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 8)                 320
#
#  dense_6 (Dense)             (None, 8)                 72
#
#  dense_7 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 401 (1.57 KB)
# Trainable params: 401 (1.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 1/1 [==============================] - 7s 7s/step - loss: 0.0042 - mean_squared_error: 0.0085 - mean_absolute_error: 0.0572 - mean_absolute_percentage_error: 97.3364
# Epoch 2/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0039 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0523 - mean_absolute_percentage_error: 73.4938
# Epoch 3/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0036 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0484 - mean_absolute_percentage_error: 72.0630
# Epoch 4/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0034 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0457 - mean_absolute_percentage_error: 82.7674
# Epoch 5/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0031 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0451 - mean_absolute_percentage_error: 106.8570
# Epoch 6/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0029 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0453 - mean_absolute_percentage_error: 135.0679
# Epoch 7/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0028 - mean_squared_error: 0.0055 - mean_absolute_error: 0.0457 - mean_absolute_percentage_error: 163.6569
# Epoch 8/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0026 - mean_squared_error: 0.0052 - mean_absolute_error: 0.0464 - mean_absolute_percentage_error: 192.3575
# Epoch 9/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0025 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0471 - mean_absolute_percentage_error: 220.3513
# Epoch 10/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0024 - mean_squared_error: 0.0048 - mean_absolute_error: 0.0479 - mean_absolute_percentage_error: 247.2928
# Epoch 11/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0023 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0488 - mean_absolute_percentage_error: 273.1768
# Epoch 12/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0022 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0497 - mean_absolute_percentage_error: 297.7177
# Epoch 13/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0022 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0506 - mean_absolute_percentage_error: 320.5950
# Epoch 14/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0022 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0515 - mean_absolute_percentage_error: 341.5517
# Epoch 15/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0021 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0524 - mean_absolute_percentage_error: 360.3745
# Epoch 16/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0021 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0531 - mean_absolute_percentage_error: 376.8308
# Epoch 17/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0021 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0538 - mean_absolute_percentage_error: 390.7236
# Epoch 18/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0021 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0543 - mean_absolute_percentage_error: 401.9648
# Epoch 19/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0021 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0547 - mean_absolute_percentage_error: 410.5003
# Epoch 20/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0021 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0548 - mean_absolute_percentage_error: 416.3340
# Epoch 21/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0021 - mean_squared_error: 0.0041 - mean_absolute_error: 0.0549 - mean_absolute_percentage_error: 419.5488
# Epoch 22/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0020 - mean_squared_error: 0.0041 - mean_absolute_error: 0.0547 - mean_absolute_percentage_error: 420.2729
# Epoch 23/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0020 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0544 - mean_absolute_percentage_error: 418.6720
# Epoch 24/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0020 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0540 - mean_absolute_percentage_error: 414.9455
# Epoch 25/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0019 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0534 - mean_absolute_percentage_error: 409.3182
# Epoch 26/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0019 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0527 - mean_absolute_percentage_error: 402.0315
# Epoch 27/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0019 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0519 - mean_absolute_percentage_error: 393.3330
# Epoch 28/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0018 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0510 - mean_absolute_percentage_error: 383.4685
# Epoch 29/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.0018 - mean_squared_error: 0.0036 - mean_absolute_error: 0.0501 - mean_absolute_percentage_error: 372.6797
# Epoch 30/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0017 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0491 - mean_absolute_percentage_error: 361.2083
#
#
# Loss St.Dev: 0.0006442449217159778 - MSE St.Dev: 0.0013033759666515223 - MAE Std.Dev: 0.0034231940060786108 - MAPE St.Dev: 125.28935486231279
#
#
# 147/147 [==============================] - 6s 39ms/step
# <ipython-input-6-c8dce139631b>:28: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# ==================== ==================== ==================== ==================== ==================== ==================== ====================
#
# ==================== ==================== ==================== ==================== ==================== ==================== ====================
#
#
# ==================== BATCH SIZE = 1024, OPT_ALG = Plain ====================
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 8)                 320
#
#  dense_8 (Dense)             (None, 8)                 72
#
#  dense_9 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 401 (1.57 KB)
# Trainable params: 401 (1.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 13/13 [==============================] - 10s 534ms/step - loss: 0.0128 - mean_squared_error: 0.0261 - mean_absolute_error: 0.0983 - mean_absolute_percentage_error: 152.5432
# Epoch 2/30
# 13/13 [==============================] - 6s 455ms/step - loss: 0.0123 - mean_squared_error: 0.0251 - mean_absolute_error: 0.0933 - mean_absolute_percentage_error: 131.1118
# Epoch 3/30
# 13/13 [==============================] - 7s 538ms/step - loss: 0.0118 - mean_squared_error: 0.0241 - mean_absolute_error: 0.0893 - mean_absolute_percentage_error: 124.9727
# Epoch 4/30
# 13/13 [==============================] - 6s 452ms/step - loss: 0.0114 - mean_squared_error: 0.0233 - mean_absolute_error: 0.0861 - mean_absolute_percentage_error: 128.1760
# Epoch 5/30
# 13/13 [==============================] - 8s 633ms/step - loss: 0.0110 - mean_squared_error: 0.0225 - mean_absolute_error: 0.0836 - mean_absolute_percentage_error: 136.4875
# Epoch 6/30
# 13/13 [==============================] - 6s 458ms/step - loss: 0.0107 - mean_squared_error: 0.0218 - mean_absolute_error: 0.0819 - mean_absolute_percentage_error: 149.4099
# Epoch 7/30
# 13/13 [==============================] - 7s 535ms/step - loss: 0.0104 - mean_squared_error: 0.0212 - mean_absolute_error: 0.0812 - mean_absolute_percentage_error: 167.8795
# Epoch 8/30
# 13/13 [==============================] - 6s 453ms/step - loss: 0.0101 - mean_squared_error: 0.0207 - mean_absolute_error: 0.0813 - mean_absolute_percentage_error: 189.7428
# Epoch 9/30
# 13/13 [==============================] - 7s 534ms/step - loss: 0.0099 - mean_squared_error: 0.0202 - mean_absolute_error: 0.0814 - mean_absolute_percentage_error: 210.3796
# Epoch 10/30
# 13/13 [==============================] - 6s 454ms/step - loss: 0.0097 - mean_squared_error: 0.0197 - mean_absolute_error: 0.0817 - mean_absolute_percentage_error: 231.1079
# Epoch 11/30
# 13/13 [==============================] - 7s 536ms/step - loss: 0.0095 - mean_squared_error: 0.0193 - mean_absolute_error: 0.0821 - mean_absolute_percentage_error: 251.1291
# Epoch 12/30
# 13/13 [==============================] - 6s 454ms/step - loss: 0.0093 - mean_squared_error: 0.0189 - mean_absolute_error: 0.0825 - mean_absolute_percentage_error: 269.9568
# Epoch 13/30
# 13/13 [==============================] - 7s 536ms/step - loss: 0.0092 - mean_squared_error: 0.0186 - mean_absolute_error: 0.0829 - mean_absolute_percentage_error: 287.5259
# Epoch 14/30
# 13/13 [==============================] - 6s 451ms/step - loss: 0.0090 - mean_squared_error: 0.0183 - mean_absolute_error: 0.0833 - mean_absolute_percentage_error: 305.1030
# Epoch 15/30
# 13/13 [==============================] - 7s 539ms/step - loss: 0.0089 - mean_squared_error: 0.0180 - mean_absolute_error: 0.0838 - mean_absolute_percentage_error: 321.4852
# Epoch 16/30
# 13/13 [==============================] - 6s 452ms/step - loss: 0.0088 - mean_squared_error: 0.0178 - mean_absolute_error: 0.0843 - mean_absolute_percentage_error: 337.3869
# Epoch 17/30
# 13/13 [==============================] - 7s 535ms/step - loss: 0.0087 - mean_squared_error: 0.0176 - mean_absolute_error: 0.0847 - mean_absolute_percentage_error: 352.1489
# Epoch 18/30
# 13/13 [==============================] - 6s 455ms/step - loss: 0.0086 - mean_squared_error: 0.0174 - mean_absolute_error: 0.0852 - mean_absolute_percentage_error: 366.6266
# Epoch 19/30
# 13/13 [==============================] - 7s 531ms/step - loss: 0.0085 - mean_squared_error: 0.0172 - mean_absolute_error: 0.0856 - mean_absolute_percentage_error: 379.7584
# Epoch 20/30
# 13/13 [==============================] - 6s 448ms/step - loss: 0.0084 - mean_squared_error: 0.0170 - mean_absolute_error: 0.0860 - mean_absolute_percentage_error: 392.5155
# Epoch 21/30
# 13/13 [==============================] - 7s 539ms/step - loss: 0.0083 - mean_squared_error: 0.0169 - mean_absolute_error: 0.0864 - mean_absolute_percentage_error: 404.2007
# Epoch 22/30
# 13/13 [==============================] - 6s 452ms/step - loss: 0.0082 - mean_squared_error: 0.0167 - mean_absolute_error: 0.0868 - mean_absolute_percentage_error: 415.7530
# Epoch 23/30
# 13/13 [==============================] - 7s 533ms/step - loss: 0.0082 - mean_squared_error: 0.0166 - mean_absolute_error: 0.0871 - mean_absolute_percentage_error: 426.6486
# Epoch 24/30
# 13/13 [==============================] - 6s 463ms/step - loss: 0.0081 - mean_squared_error: 0.0165 - mean_absolute_error: 0.0874 - mean_absolute_percentage_error: 436.9788
# Epoch 25/30
# 13/13 [==============================] - 7s 543ms/step - loss: 0.0081 - mean_squared_error: 0.0164 - mean_absolute_error: 0.0878 - mean_absolute_percentage_error: 446.9444
# Epoch 26/30
# 13/13 [==============================] - 6s 453ms/step - loss: 0.0080 - mean_squared_error: 0.0163 - mean_absolute_error: 0.0881 - mean_absolute_percentage_error: 455.8810
# Epoch 27/30
# 13/13 [==============================] - 7s 536ms/step - loss: 0.0080 - mean_squared_error: 0.0162 - mean_absolute_error: 0.0884 - mean_absolute_percentage_error: 464.8147
# Epoch 28/30
# 13/13 [==============================] - 6s 453ms/step - loss: 0.0079 - mean_squared_error: 0.0161 - mean_absolute_error: 0.0887 - mean_absolute_percentage_error: 473.1693
# Epoch 29/30
# 13/13 [==============================] - 7s 535ms/step - loss: 0.0079 - mean_squared_error: 0.0160 - mean_absolute_error: 0.0890 - mean_absolute_percentage_error: 481.3437
# Epoch 30/30
# 13/13 [==============================] - 6s 453ms/step - loss: 0.0079 - mean_squared_error: 0.0159 - mean_absolute_error: 0.0893 - mean_absolute_percentage_error: 488.9068
#
#
# Loss St.Dev: 0.0014109928449456638 - MSE St.Dev: 0.0029209429496643512 - MAE Std.Dev: 0.003814558334543194 - MAPE St.Dev: 125.32693830946121
#
#
# 147/147 [==============================] - 7s 48ms/step
# <ipython-input-6-c8dce139631b>:28: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# ==================== ==================== ==================== ==================== ==================== ==================== ====================
#
# ==================== ==================== ==================== ==================== ==================== ==================== ====================
#
#
# ==================== BATCH SIZE = 1024, OPT_ALG = Momentum ====================
#
#
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 8)                 320
#
#  dense_10 (Dense)            (None, 8)                 72
#
#  dense_11 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 401 (1.57 KB)
# Trainable params: 401 (1.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 13/13 [==============================] - 9s 519ms/step - loss: 0.0030 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0471 - mean_absolute_percentage_error: 71.7551
# Epoch 2/30
# 13/13 [==============================] - 6s 452ms/step - loss: 0.0026 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0410 - mean_absolute_percentage_error: 72.3977
# Epoch 3/30
# 13/13 [==============================] - 7s 515ms/step - loss: 0.0023 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0405 - mean_absolute_percentage_error: 125.9334
# Epoch 4/30
# 13/13 [==============================] - 7s 558ms/step - loss: 0.0021 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0421 - mean_absolute_percentage_error: 180.8506
# Epoch 5/30
# 13/13 [==============================] - 7s 495ms/step - loss: 0.0020 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0436 - mean_absolute_percentage_error: 222.5311
# Epoch 6/30
# 13/13 [==============================] - 6s 472ms/step - loss: 0.0020 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0449 - mean_absolute_percentage_error: 251.9452
# Epoch 7/30
# 13/13 [==============================] - 7s 497ms/step - loss: 0.0019 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0458 - mean_absolute_percentage_error: 272.2956
# Epoch 8/30
# 13/13 [==============================] - 6s 472ms/step - loss: 0.0019 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0465 - mean_absolute_percentage_error: 286.8629
# Epoch 9/30
# 13/13 [==============================] - 7s 498ms/step - loss: 0.0019 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0469 - mean_absolute_percentage_error: 296.0689
# Epoch 10/30
# 13/13 [==============================] - 6s 474ms/step - loss: 0.0019 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0472 - mean_absolute_percentage_error: 301.8101
# Epoch 11/30
# 13/13 [==============================] - 7s 497ms/step - loss: 0.0019 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0474 - mean_absolute_percentage_error: 305.8669
# Epoch 12/30
# 13/13 [==============================] - 6s 476ms/step - loss: 0.0019 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0475 - mean_absolute_percentage_error: 308.7059
# Epoch 13/30
# 13/13 [==============================] - 7s 495ms/step - loss: 0.0019 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0476 - mean_absolute_percentage_error: 310.6110
# Epoch 14/30
# 13/13 [==============================] - 6s 474ms/step - loss: 0.0019 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0476 - mean_absolute_percentage_error: 311.5000
# Epoch 15/30
# 13/13 [==============================] - 7s 503ms/step - loss: 0.0019 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0476 - mean_absolute_percentage_error: 312.0026
# Epoch 16/30
# 13/13 [==============================] - 6s 484ms/step - loss: 0.0019 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0476 - mean_absolute_percentage_error: 312.2339
# Epoch 17/30
# 13/13 [==============================] - 7s 494ms/step - loss: 0.0019 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0475 - mean_absolute_percentage_error: 312.2234
# Epoch 18/30
# 13/13 [==============================] - 6s 488ms/step - loss: 0.0019 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0475 - mean_absolute_percentage_error: 312.5083
# Epoch 19/30
# 13/13 [==============================] - 7s 488ms/step - loss: 0.0019 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0475 - mean_absolute_percentage_error: 312.3378
# Epoch 20/30
# 13/13 [==============================] - 6s 487ms/step - loss: 0.0019 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0474 - mean_absolute_percentage_error: 311.9688
# Epoch 21/30
# 13/13 [==============================] - 7s 485ms/step - loss: 0.0019 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0474 - mean_absolute_percentage_error: 311.7408
# Epoch 22/30
# 13/13 [==============================] - 6s 494ms/step - loss: 0.0019 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0473 - mean_absolute_percentage_error: 311.4702
# Epoch 23/30
# 13/13 [==============================] - 6s 482ms/step - loss: 0.0018 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0473 - mean_absolute_percentage_error: 311.2001
# Epoch 24/30
# 13/13 [==============================] - 6s 493ms/step - loss: 0.0018 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0473 - mean_absolute_percentage_error: 310.9597
# Epoch 25/30
# 13/13 [==============================] - 6s 482ms/step - loss: 0.0018 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0472 - mean_absolute_percentage_error: 310.4749
# Epoch 26/30
# 13/13 [==============================] - 6s 494ms/step - loss: 0.0018 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0472 - mean_absolute_percentage_error: 310.1941
# Epoch 27/30
# 13/13 [==============================] - 6s 477ms/step - loss: 0.0018 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0471 - mean_absolute_percentage_error: 309.6433
# Epoch 28/30
# 13/13 [==============================] - 6s 492ms/step - loss: 0.0018 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0470 - mean_absolute_percentage_error: 309.1816
# Epoch 29/30
# 13/13 [==============================] - 6s 476ms/step - loss: 0.0018 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0470 - mean_absolute_percentage_error: 309.1056
# Epoch 30/30
# 13/13 [==============================] - 6s 487ms/step - loss: 0.0018 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0469 - mean_absolute_percentage_error: 308.7419
#
#
# Loss St.Dev: 0.00026210209091687814 - MSE St.Dev: 0.000529279244818571 - MAE Std.Dev: 0.001974813554791642 - MAPE St.Dev: 70.32373984383621
#
#
# 147/147 [==============================] - 7s 48ms/step
# <ipython-input-6-c8dce139631b>:28: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <ipython-input-6-c8dce139631b>:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(6, 4))
# ==================== ==================== ==================== ==================== ==================== ==================== ====================
#
# ==================== ==================== ==================== ==================== ==================== ==================== ====================
#
#
# ==================== BATCH SIZE = 1024, OPT_ALG = RMSprop ====================
#
#
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 8)                 320
#
#  dense_12 (Dense)            (None, 8)                 72
#
#  dense_13 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 401 (1.57 KB)
# Trainable params: 401 (1.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 13/13 [==============================] - 9s 535ms/step - loss: 0.0022 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0430 - mean_absolute_percentage_error: 172.8745
# Epoch 2/30
# 13/13 [==============================] - 6s 481ms/step - loss: 0.0014 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0416 - mean_absolute_percentage_error: 276.5745
# Epoch 3/30
# 13/13 [==============================] - 10s 782ms/step - loss: 9.5546e-04 - mean_squared_error: 0.0019 - mean_absolute_error: 0.0347 - mean_absolute_percentage_error: 238.9797
# Epoch 4/30
# 13/13 [==============================] - 6s 452ms/step - loss: 4.3038e-04 - mean_squared_error: 8.6128e-04 - mean_absolute_error: 0.0230 - mean_absolute_percentage_error: 159.2445
# Epoch 5/30
# 13/13 [==============================] - 7s 534ms/step - loss: 7.2500e-05 - mean_squared_error: 1.4502e-04 - mean_absolute_error: 0.0087 - mean_absolute_percentage_error: 62.4758
# Epoch 6/30
# 13/13 [==============================] - 6s 463ms/step - loss: 1.0872e-05 - mean_squared_error: 2.1746e-05 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 23.4187
# Epoch 7/30
# 13/13 [==============================] - 7s 539ms/step - loss: 9.2536e-06 - mean_squared_error: 1.8507e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 21.5019
# Epoch 8/30
# 13/13 [==============================] - 6s 460ms/step - loss: 9.0809e-06 - mean_squared_error: 1.8161e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 20.1918
# Epoch 9/30
# 13/13 [==============================] - 7s 535ms/step - loss: 8.5220e-06 - mean_squared_error: 1.7045e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 20.0781
# Epoch 10/30
# 13/13 [==============================] - 6s 453ms/step - loss: 9.0309e-06 - mean_squared_error: 1.8062e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 20.7885
# Epoch 11/30
# 13/13 [==============================] - 7s 536ms/step - loss: 9.0182e-06 - mean_squared_error: 1.8037e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 21.8991
# Epoch 12/30
# 13/13 [==============================] - 6s 447ms/step - loss: 9.1070e-06 - mean_squared_error: 1.8213e-05 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 20.9240
# Epoch 13/30
# 13/13 [==============================] - 7s 531ms/step - loss: 9.0254e-06 - mean_squared_error: 1.8051e-05 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 22.1004
# Epoch 14/30
# 13/13 [==============================] - 6s 449ms/step - loss: 9.1608e-06 - mean_squared_error: 1.8321e-05 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 20.9545
# Epoch 15/30
# 13/13 [==============================] - 7s 534ms/step - loss: 8.2086e-06 - mean_squared_error: 1.6417e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 21.1441
# Epoch 16/30
# 13/13 [==============================] - 6s 451ms/step - loss: 9.2913e-06 - mean_squared_error: 1.8583e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 21.1723
# Epoch 17/30
# 13/13 [==============================] - 7s 534ms/step - loss: 9.2906e-06 - mean_squared_error: 1.8582e-05 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 22.6579
# Epoch 18/30
# 13/13 [==============================] - 6s 449ms/step - loss: 8.7835e-06 - mean_squared_error: 1.7567e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 20.3885
# Epoch 19/30
# 13/13 [==============================] - 7s 531ms/step - loss: 8.9655e-06 - mean_squared_error: 1.7931e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 21.6023
# Epoch 20/30
# ...
# Epoch 13/30
# 104/104 [==============================] - 22s 214ms/step - loss: 2.0951e-06 - mean_squared_error: 4.1888e-06 - mean_absolute_error: 0.0012 - mean_absolute_percentage_error: 5.4252
# Epoch 14/30
# 104/104 [==============================] - 21s 201ms/step - loss: 2.0727e-06 - mean_squared_error: 4.1441e-06 - mean_absolute_error: 0.0012 - mean_absolute_percentage_error: 5.3275
# Epoch 15/30
# 104/104 [==============================] - 22s 214ms/step - loss: 1.9996e-06 - mean_squared_error: 3.9991e-06 - mean_absolute_error: 0.0011 - mean_absolute_percentage_error: 4.9662
# Epoch 16/30
# 104/104 [==============================] - 22s 214ms/step - loss: 2.0526e-06 - mean_squared_error: 4.1041e-06 - mean_absolute_error: 0.0012 - mean_absolute_percentage_error: 5.1035
# Epoch 17/30
# 104/104 [==============================] - 21s 201ms/step - loss: 2.0207e-06 - mean_squared_error: 4.0407e-06 - mean_absolute_error: 0.0012 - mean_absolute_percentage_error: 5.2517
# Epoch 18/30
# 104/104 [==============================] - 22s 215ms/step - loss: 2.0001e-06 - mean_squared_error: 3.9986e-06 - mean_absolute_error: 0.0012 - mean_absolute_percentage_error: 5.0270
# Epoch 19/30
# 104/104 [==============================] - 22s 214ms/step - loss: 1.9250e-06 - mean_squared_error: 3.8494e-06 - mean_absolute_error: 0.0011 - mean_absolute_percentage_error: 4.8651
# Epoch 20/30
# 104/104 [==============================] - 21s 202ms/step - loss: 1.9352e-06 - mean_squared_error: 3.8692e-06 - mean_absolute_error: 0.0011 - mean_absolute_percentage_error: 4.9304
# Epoch 21/30
# 104/104 [==============================] - 22s 215ms/step - loss: 1.8313e-06 - mean_squared_error: 3.6607e-06 - mean_absolute_error: 0.0011 - mean_absolute_percentage_error: 4.3357
# Epoch 22/30
# 104/104 [==============================] - 24s 228ms/step - loss: 1.8298e-06 - mean_squared_error: 3.6585e-06 - mean_absolute_error: 0.0011 - mean_absolute_percentage_error: 4.5454
# Epoch 23/30
# 104/104 [==============================] - 22s 210ms/step - loss: 1.8404e-06 - mean_squared_error: 3.6789e-06 - mean_absolute_error: 0.0011 - mean_absolute_percentage_error: 4.4631
# Epoch 24/30
# 104/104 [==============================] - 22s 207ms/step - loss: 1.8897e-06 - mean_squared_error: 3.7778e-06 - mean_absolute_error: 0.0011 - mean_absolute_percentage_error: 4.9175
# Epoch 25/30
# 104/104 [==============================] - 22s 214ms/step - loss: 1.9503e-06 - mean_squared_error: 3.8994e-06 - mean_absolute_error: 0.0012 - mean_absolute_percentage_error: 5.3798
# Epoch 26/30
# 104/104 [==============================] - 22s 213ms/step - loss: 1.8054e-06 - mean_squared_error: 3.6095e-06 - mean_absolute_error: 0.0011 - mean_absolute_percentage_error: 4.8334
# Epoch 27/30
# 104/104 [==============================] - 21s 203ms/step - loss: 1.8100e-06 - mean_squared_error: 3.6185e-06 - mean_absolute_error: 0.0011 - mean_absolute_percentage_error: 4.8902
# Epoch 28/30
# 104/104 [==============================] - 22s 215ms/step - loss: 1.7448e-06 - mean_squared_error: 3.4891e-06 - mean_absolute_error: 0.0011 - mean_absolute_percentage_error: 4.6162
# Epoch 29/30
# 104/104 [==============================] - 22s 216ms/step - loss: 1.6467e-06 - mean_squared_error: 3.2925e-06 - mean_absolute_error: 0.0010 - mean_absolute_percentage_error: 4.0605
# Epoch 30/30
# 104/104 [==============================] - 21s 202ms/step - loss: 1.7305e-06 - mean_squared_error: 3.4600e-06 - mean_absolute_error: 0.0011 - mean_absolute_percentage_error: 4.7728
#
#
# Loss St.Dev: 0.00016690340099521144 - MSE St.Dev: 0.0003347702464856987 - MAE Std.Dev: 0.004516643343637615 - MAPE St.Dev: 29.78776069988854
#
#
# 147/147 [==============================] - 8s 49ms/step
# <ipython-input-6-c8dce139631b>:28: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# ==================== ==================== ==================== ==================== ==================== ==================== ====================
#
# ==================== ==================== ==================== ==================== ==================== ==================== ====================
#
#
# ==================== BATCH SIZE = 64, OPT_ALG = Plain ====================
#
#
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_16 (LSTM)              (None, 8)                 320
#
#  dense_32 (Dense)            (None, 8)                 72
#
#  dense_33 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 401 (1.57 KB)
# Trainable params: 401 (1.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 208/208 [==============================] - 42s 192ms/step - loss: 0.0039 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0511 - mean_absolute_percentage_error: 78.8528
# Epoch 2/30
# 208/208 [==============================] - 39s 186ms/step - loss: 0.0034 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0473 - mean_absolute_percentage_error: 128.2262
# Epoch 3/30
# 208/208 [==============================] - 39s 186ms/step - loss: 0.0030 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0490 - mean_absolute_percentage_error: 192.8670
# Epoch 4/30
# 208/208 [==============================] - 39s 186ms/step - loss: 0.0029 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0506 - mean_absolute_percentage_error: 240.4231
# Epoch 5/30
# 208/208 [==============================] - 38s 185ms/step - loss: 0.0028 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0520 - mean_absolute_percentage_error: 276.0706
# Epoch 6/30
# 208/208 [==============================] - 39s 185ms/step - loss: 0.0027 - mean_squared_error: 0.0055 - mean_absolute_error: 0.0531 - mean_absolute_percentage_error: 301.4302
# Epoch 7/30
# 208/208 [==============================] - 40s 193ms/step - loss: 0.0027 - mean_squared_error: 0.0054 - mean_absolute_error: 0.0539 - mean_absolute_percentage_error: 320.1581
# Epoch 8/30
# 208/208 [==============================] - 39s 188ms/step - loss: 0.0027 - mean_squared_error: 0.0054 - mean_absolute_error: 0.0545 - mean_absolute_percentage_error: 332.8895
# Epoch 9/30
# 208/208 [==============================] - 39s 189ms/step - loss: 0.0027 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0549 - mean_absolute_percentage_error: 342.5265
# Epoch 10/30
# 208/208 [==============================] - 39s 189ms/step - loss: 0.0026 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0552 - mean_absolute_percentage_error: 349.1737
# Epoch 11/30
# 208/208 [==============================] - 39s 189ms/step - loss: 0.0026 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0554 - mean_absolute_percentage_error: 353.8248
# Epoch 12/30
# 208/208 [==============================] - 39s 189ms/step - loss: 0.0026 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0555 - mean_absolute_percentage_error: 357.1770
# Epoch 13/30
# 208/208 [==============================] - 40s 193ms/step - loss: 0.0026 - mean_squared_error: 0.0052 - mean_absolute_error: 0.0556 - mean_absolute_percentage_error: 359.6234
# Epoch 14/30
# 208/208 [==============================] - 39s 186ms/step - loss: 0.0026 - mean_squared_error: 0.0052 - mean_absolute_error: 0.0556 - mean_absolute_percentage_error: 360.2807
# Epoch 15/30
# 208/208 [==============================] - 39s 185ms/step - loss: 0.0026 - mean_squared_error: 0.0052 - mean_absolute_error: 0.0556 - mean_absolute_percentage_error: 361.1765
# Epoch 16/30
# 208/208 [==============================] - 38s 185ms/step - loss: 0.0026 - mean_squared_error: 0.0052 - mean_absolute_error: 0.0556 - mean_absolute_percentage_error: 362.1105
# Epoch 17/30
# 208/208 [==============================] - 39s 185ms/step - loss: 0.0026 - mean_squared_error: 0.0052 - mean_absolute_error: 0.0555 - mean_absolute_percentage_error: 362.5403
# Epoch 18/30
# 208/208 [==============================] - 39s 188ms/step - loss: 0.0026 - mean_squared_error: 0.0052 - mean_absolute_error: 0.0554 - mean_absolute_percentage_error: 361.4354
# Epoch 19/30
# 208/208 [==============================] - 39s 189ms/step - loss: 0.0026 - mean_squared_error: 0.0051 - mean_absolute_error: 0.0554 - mean_absolute_percentage_error: 361.8912
# Epoch 20/30
# 208/208 [==============================] - 39s 186ms/step - loss: 0.0026 - mean_squared_error: 0.0051 - mean_absolute_error: 0.0553 - mean_absolute_percentage_error: 361.4953
# Epoch 21/30
# 208/208 [==============================] - 38s 182ms/step - loss: 0.0025 - mean_squared_error: 0.0051 - mean_absolute_error: 0.0552 - mean_absolute_percentage_error: 360.2256
# Epoch 22/30
# 208/208 [==============================] - 38s 182ms/step - loss: 0.0025 - mean_squared_error: 0.0051 - mean_absolute_error: 0.0552 - mean_absolute_percentage_error: 360.9006
# Epoch 23/30
# 208/208 [==============================] - 38s 183ms/step - loss: 0.0025 - mean_squared_error: 0.0051 - mean_absolute_error: 0.0551 - mean_absolute_percentage_error: 360.3246
# Epoch 24/30
# 208/208 [==============================] - 41s 196ms/step - loss: 0.0025 - mean_squared_error: 0.0051 - mean_absolute_error: 0.0550 - mean_absolute_percentage_error: 359.3754
# Epoch 25/30
# 208/208 [==============================] - 38s 182ms/step - loss: 0.0025 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0549 - mean_absolute_percentage_error: 359.1149
# Epoch 26/30
# 208/208 [==============================] - 38s 184ms/step - loss: 0.0025 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0548 - mean_absolute_percentage_error: 357.5221
# Epoch 27/30
# 208/208 [==============================] - 38s 184ms/step - loss: 0.0025 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0547 - mean_absolute_percentage_error: 357.5576
# Epoch 28/30
# 208/208 [==============================] - 39s 186ms/step - loss: 0.0025 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0546 - mean_absolute_percentage_error: 356.5481
# Epoch 29/30
# 208/208 [==============================] - 39s 186ms/step - loss: 0.0025 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0545 - mean_absolute_percentage_error: 356.5103
# Epoch 30/30
# 208/208 [==============================] - 40s 193ms/step - loss: 0.0025 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0544 - mean_absolute_percentage_error: 355.2209
#
#
# Loss St.Dev: 0.0002997529929329351 - MSE St.Dev: 0.0006079531060257525 - MAE Std.Dev: 0.002091661295986921 - MAPE St.Dev: 72.25790986418299
#
#
# 147/147 [==============================] - 8s 49ms/step
# <ipython-input-6-c8dce139631b>:28: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# ==================== ==================== ==================== ==================== ==================== ==================== ====================
#
# ==================== ==================== ==================== ==================== ==================== ==================== ====================
#
#
# ==================== BATCH SIZE = 64, OPT_ALG = Momentum ====================
#
#
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_17 (LSTM)              (None, 8)                 320
#
#  dense_34 (Dense)            (None, 8)                 72
#
#  dense_35 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 401 (1.57 KB)
# Trainable params: 401 (1.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 208/208 [==============================] - 42s 186ms/step - loss: 0.0027 - mean_squared_error: 0.0055 - mean_absolute_error: 0.0512 - mean_absolute_percentage_error: 258.8932
# Epoch 2/30
# 208/208 [==============================] - 39s 187ms/step - loss: 0.0024 - mean_squared_error: 0.0049 - mean_absolute_error: 0.0541 - mean_absolute_percentage_error: 355.3664
# Epoch 3/30
# 208/208 [==============================] - 39s 187ms/step - loss: 0.0024 - mean_squared_error: 0.0048 - mean_absolute_error: 0.0538 - mean_absolute_percentage_error: 355.9177
# Epoch 4/30
# 208/208 [==============================] - 39s 187ms/step - loss: 0.0023 - mean_squared_error: 0.0047 - mean_absolute_error: 0.0532 - mean_absolute_percentage_error: 351.5283
# Epoch 5/30
# 208/208 [==============================] - 39s 187ms/step - loss: 0.0023 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0527 - mean_absolute_percentage_error: 348.5704
# Epoch 6/30
# 208/208 [==============================] - 41s 195ms/step - loss: 0.0022 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0522 - mean_absolute_percentage_error: 345.2011
# Epoch 7/30
# 208/208 [==============================] - 39s 187ms/step - loss: 0.0022 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0517 - mean_absolute_percentage_error: 341.8021
# Epoch 8/30
# 208/208 [==============================] - 39s 188ms/step - loss: 0.0021 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0512 - mean_absolute_percentage_error: 339.0172
# Epoch 9/30
# 208/208 [==============================] - 39s 187ms/step - loss: 0.0021 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0506 - mean_absolute_percentage_error: 335.3768
# Epoch 10/30
# 208/208 [==============================] - 39s 186ms/step - loss: 0.0021 - mean_squared_error: 0.0041 - mean_absolute_error: 0.0499 - mean_absolute_percentage_error: 329.0949
# Epoch 11/30
# 208/208 [==============================] - 39s 188ms/step - loss: 0.0020 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0495 - mean_absolute_percentage_error: 326.8070
# Epoch 12/30
# 208/208 [==============================] - 40s 193ms/step - loss: 0.0020 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0492 - mean_absolute_percentage_error: 327.9470
# Epoch 13/30
# 208/208 [==============================] - 39s 186ms/step - loss: 0.0019 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0482 - mean_absolute_percentage_error: 316.1056
# Epoch 14/30
# 208/208 [==============================] - 39s 187ms/step - loss: 0.0019 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0479 - mean_absolute_percentage_error: 316.5415
# Epoch 15/30
# 208/208 [==============================] - 39s 187ms/step - loss: 0.0018 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0473 - mean_absolute_percentage_error: 313.2162
# Epoch 16/30
# 208/208 [==============================] - 39s 188ms/step - loss: 0.0018 - mean_squared_error: 0.0036 - mean_absolute_error: 0.0467 - mean_absolute_percentage_error: 308.0047
# Epoch 17/30
# 208/208 [==============================] - 40s 195ms/step - loss: 0.0018 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0463 - mean_absolute_percentage_error: 307.0162
# Epoch 18/30
# 171/208 [=======================>......] - ETA: 6s - loss: 0.0017 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0456 - mean_absolute_percentage_error: 299.8629
